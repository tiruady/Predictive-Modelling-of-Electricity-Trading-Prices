# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
#  delaware   maryland	 'North Carolina'   Tennessee
#  Illinois   Michigan	  ohio		    Virginia
#  Indiana   'New Jersey'   Pennysylvania    'West Virginia'

# %%
# !cd sample_data;ls
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
cd sample data
# Out:
# [Errno 2] No such file or directory: 'sample data'
# /content

# %%
# !cd ../..

# %%
# !ls
# Out:
# sample_data

# %%
cd ..
# Out:
# /

# %%
ls
# Out:
# bin/      dev/   lib32/  opt/   sbin/   tensorflow-2.0.0/  var/
# boot/     etc/   lib64/  proc/  srv/    tmp/
# content/  home/  media/  root/  swift/  tools/
# datalab/  lib/   mnt/    run/   sys/    usr/

# %%
from google.colab import drive

# %%
# !cd content
# Out:
# /bin/bash: line 0: cd: content: No such file or directory

# %%
# !cd /

# %%
drive.mount(‘/content/gdrive’)
# Out:
#   File "<ipython-input-26-d80f7fd30895>", line 1
#     drive.mount(‘/content/gdrive’)
#                 ^
# SyntaxError: invalid character in identifier

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df=pd.read_csv('/content/gdrive/My Drive/virginia/1149975_41.25_-76.9_2001.csv', skiprows=2)

# %%
root_path = 'gdrive/My Drive/your_project_folder/'

# %%
# !cd /content/gdrive/pennysylvania
# Out:
# /bin/bash: line 0: cd: /content/gdrive/pennysylvania: No such file or directory

# %%
# !cd ../..

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
cd gdrive
# Out:
# /content/gdrive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd 'My Drive'
# Out:
# /content/gdrive/My Drive

# %%
ls

# %%
df.head(n=49)

# %%
df.dtypes
# Out:
# Year                  object
# Month                  int64
# Day                    int64
# Hour                   int64
# Minute                 int64
# DHI                    int64
# DNI                    int64
# Clearsky DNI           int64
# Relative Humidity    float64
# Temperature            int64
# Pressure             float64
# dtype: object

# %%
df['Year']=df['Year'].astype(str)
df['Month']=df['Month'].astype(str)
df['date']=df["Year"].astype(str)+'/'+df["Month"].astype(str)+'/'+df['Day'].astype(str)
# df['date']=pd.to_datetime(df['date'])
df['datetime']=df['date']+' '+df['Hour'].astype(str)+':'+df['Minute'].astype(str)
df['datetime']=pd.to_datetime(df['datetime'], format='%Y/%m/%d %H:%M')

# %%
df['datetime']=df['date']+' '+df['Hour'].astype(str)+':'+df['Minute'].astype(str)
df['datetime']=pd.to_datetime(df['datetime'], format='%Y/%m/%d %H:%M')

# %%
from datetime import datetime
b=datetime.strptime(s,'%Y/%m/%d')

# %%
s=df['datetime'][3];s
# Out:
# Timestamp('2001-01-01 01:30:00')

# %%
df.dtypes
# Out:
# Year                         object
# Month                        object
# Day                           int64
# Hour                          int64
# Minute                        int64
# DHI                           int64
# DNI                           int64
# Wind Speed                  float64
# Relative Humidity           float64
# Temperature                   int64
# Pressure                    float64
# date                         object
# datetime             datetime64[ns]
# dtype: object

# %%
df.head(n=30)
# Out:
#     Year Month  Day  Hour  ...  Temperature  Pressure      date        datetime
# 0   2001     1    1     0  ...           -5     980.0  2001/1/1    2001/1/1 0:0
# 1   2001     1    1     0  ...           -5     980.0  2001/1/1   2001/1/1 0:30
# 2   2001     1    1     1  ...           -6     980.0  2001/1/1    2001/1/1 1:0
# 3   2001     1    1     1  ...           -6     980.0  2001/1/1   2001/1/1 1:30
# 4   2001     1    1     2  ...           -6     980.0  2001/1/1    2001/1/1 2:0
# 5   2001     1    1     2  ...           -6     990.0  2001/1/1   2001/1/1 2:30
# 6   2001     1    1     3  ...           -7     990.0  2001/1/1    2001/1/1 3:0
# 7   2001     1    1     3  ...           -7     990.0  2001/1/1   2001/1/1 3:30
# 8   2001     1    1     4  ...           -7     990.0  2001/1/1    2001/1/1 4:0
# 9   2001     1    1     4  ...           -7     990.0  2001/1/1   2001/1/1 4:30
# 10  2001     1    1     5  ...           -7     990.0  2001/1/1    2001/1/1 5:0
# ...

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# 'B.Tech- 1st Sem (5041)-(SEC-C).pdf'
# 'Case study.gslides'
# 'Colab Notebooks'/
# 'Computer System Architecture - Morris Mano - IIIrd Edition (1).pdf'
# 'Computer System Architecture - Morris Mano - IIIrd Edition.pdf'
#  CSS01.mkv
# 'daa_2_a (1).gdoc'
#  daa_2_a.gdoc
#  daa_2_a.pdf
# 'DAA3 (1).doc'
# 'DAA3 (1).gdoc'
# 'DAA3 (2).gdoc'
# 'DAA3 (3).gdoc'
#  DAA3.doc
#  DAA3.gdoc
# 'DAA432C_Spring2019_paper_122 (2).gdoc'
# 'DAA432C_Spring2019_paper_122 (2).pdf'
#  DAA4.doc
#  DAA4.gdoc
#  DAA5.gdoc
#  Data/
#  datasets/
#  datasets2/
#  delaware/
#  difference.pdf
# 'Document from STAN'
# 'Document from STAN (1)'
# 'Document from STAN (2)'
# 'Document from STAN (3)'
# 'DST_Attendence(Theory).xlsx'
# 'DST_Attendence(Theory).xlsx.gsheet'
# 'End SEM Exam Schedule Nov. 17-1.xls'
# 'End Sem Exam Schedule Nov Dec - Revised-2.xls'
#  geometryalgorithms.pdf
# 'Getting started.pdf'
# 'Git and Github LIVE Webinar - Arnav Gupta _ Coding Blocks - YouTube.mkv'
# ' Github Pages) playerWebinar18.mkv'
# ...

# %%
# !ls
# Out:
# 'B.Tech- 1st Sem (5041)-(SEC-C).pdf'
# 'Case study.gslides'
# 'Colab Notebooks'
# 'Computer System Architecture - Morris Mano - IIIrd Edition (1).pdf'
# 'Computer System Architecture - Morris Mano - IIIrd Edition.pdf'
#  CSS01.mkv
# 'daa_2_a (1).gdoc'
#  daa_2_a.gdoc
#  daa_2_a.pdf
# 'DAA3 (1).doc'
# 'DAA3 (1).gdoc'
# 'DAA3 (2).gdoc'
# 'DAA3 (3).gdoc'
#  DAA3.doc
#  DAA3.gdoc
# 'DAA432C_Spring2019_paper_122 (2).gdoc'
# 'DAA432C_Spring2019_paper_122 (2).pdf'
#  DAA4.doc
#  DAA4.gdoc
#  DAA5.gdoc
#  Data
#  DatasetStates
#  difference.pdf
# 'Document from STAN'
# 'Document from STAN (1)'
# 'Document from STAN (2)'
# 'Document from STAN (3)'
# 'DST_Attendence(Theory).xlsx'
# 'DST_Attendence(Theory).xlsx.gsheet'
# 'End SEM Exam Schedule Nov. 17-1.xls'
# 'End Sem Exam Schedule Nov Dec - Revised-2.xls'
#  geometryalgorithms.pdf
# 'Getting started.pdf'
# 'Git and Github LIVE Webinar - Arnav Gupta _ Coding Blocks - YouTube.mkv'
# ' Github Pages) playerWebinar18.mkv'
# '^GSPC (1).csv'
# ...

# %%
cd DatasetStates/
# Out:
# /content/drive/My Drive/DatasetStates

# %%
import os
from pathlib import Path
import random

# %%
p = Path("/content/drive/My Drive/DatasetStates")
random.seed(0)
dirs = p.glob("*")

# %%
for folder_dir in dirs:
  q=Path(str(folder_dir))
  random.seed(0)
  dir2=q.glob("*")
  for year in dir2:
    last=str(year).split(".")[2].split("_")[-1]
    print(last)

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/My Drive/DatasetStates/Illinois/856646_40.65_-89.7_2000.csv",skiprows=2)

# %%
df.head(n=24)
# Out:
#     Year  Month  Day  ...  Relative Humidity  Temperature  Pressure
# 0   2000      1    1  ...              89.83            0     990.0
# 1   2000      1    1  ...              89.82            0     990.0
# 2   2000      1    1  ...              93.86           -1     990.0
# 3   2000      1    1  ...              93.85           -1     990.0
# 4   2000      1    1  ...              91.64           -1     990.0
# 5   2000      1    1  ...              91.63           -1     990.0
# 6   2000      1    1  ...              90.38           -1     990.0
# 7   2000      1    1  ...              90.38           -1     990.0
# 8   2000      1    1  ...              90.01           -1     990.0
# 9   2000      1    1  ...              90.01           -1     990.0
# 10  2000      1    1  ...              90.32           -1     990.0
# 11  2000      1    1  ...              90.33           -1     990.0
# 12  2000      1    1  ...              91.56           -1     990.0
# ...

# %%
weights=pd.read_excel('/content/gdrive/My Drive/Prod_dataset.xlsx')
w2=weights[weights['MSN']=='SOTCB']
finalweights=w2[(w2['StateCode']=='IL') | (w2['StateCode']=='IN') | (w2['StateCode']=='OH') | (w2['StateCode']=='VA') | (w2['StateCode']=='WV')| (w2['StateCode']=='DE')| (w2['StateCode']=='MD')| (w2['StateCode']=='MI')| (w2['StateCode']=='NC')| (w2['StateCode']=='NJ')| (w2['StateCode']=='PA')| (w2['StateCode']=='TN')]

# %%
fw=finalweights[['StateCode',2000,
                2001,          2002,          2003,          2004,
                2005,          2006,          2007,          2008,
                2009,          2010,          2011,          2012,
                2013,          2014,          2015,          2016,
                2017]]

# %%
fw
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-32677a55b783> in <module>()
# ----> 1 fw
#
# NameError: name 'fw' is not defined

# %%
fw=pd.read_csv("/content/drive/My Drive/final_weights.csv")

# %%
fw.head()
# Out:
#    DE   20.0   17.0   16.0   13.0  ...  1001.0  1189.0   1230.0   1133.0   1354.0
# 0  IL  208.0  248.0  326.0  393.0  ...  1797.0  1892.0   1936.0   2029.0   2284.0
# 1  IN   33.0   35.0   38.0   37.0  ...   488.0  1205.0   1713.0   2391.0   3032.0
# 2  MD   44.0   42.0   40.0   38.0  ...  2224.0  3449.0   4375.0   6834.0   9348.0
# 3  MI  229.0  219.0  210.0  199.0  ...   765.0   816.0    852.0   1087.0   1692.0
# 4  NC  127.0  111.0  100.0   85.0  ...  4155.0  7898.0  13870.0  33396.0  49100.0
#
# [5 rows x 19 columns]

# %%
fw=pd.read_csv("/content/final_weights.csv")

# %%
fw.head(n=12)
# Out:
#    StateCode   2000   2001   2002  ...     2014     2015     2016     2017
# 0         DE   20.0   17.0   16.0  ...   1189.0   1230.0   1133.0   1354.0
# 1         IL  208.0  248.0  326.0  ...   1892.0   1936.0   2029.0   2284.0
# 2         IN   33.0   35.0   38.0  ...   1205.0   1713.0   2391.0   3032.0
# 3         MD   44.0   42.0   40.0  ...   3449.0   4375.0   6834.0   9348.0
# 4         MI  229.0  219.0  210.0  ...    816.0    852.0   1087.0   1692.0
# 5         NC  127.0  111.0  100.0  ...   7898.0  13870.0  33396.0  49100.0
# 6         NJ  643.0  669.0  954.0  ...  19679.0  20963.0  22255.0  25629.0
# 7         OH  100.0  100.0  119.0  ...   1566.0   1678.0   1873.0   2435.0
# 8         PA  437.0  408.0  397.0  ...   3707.0   3756.0   4068.0   4683.0
# 9         TN   53.0   50.0   44.0  ...    856.0   1294.0   1545.0   1679.0
# 10        VA  136.0  146.0  178.0  ...    728.0    802.0   1103.0   4034.0
# ...

# %%
fw['2018']=0

# %%
fw.head()
# Out:
#   StateCode   2000   2001   2002   2003  ...    2015    2016    2017  2018  2018
# 0        DE   20.0   17.0   16.0   13.0  ...  1230.0  1133.0  1354.0     0     0
# 1        IL  208.0  248.0  326.0  393.0  ...  1936.0  2029.0  2284.0     0     0
# 2        IN   33.0   35.0   38.0   37.0  ...  1713.0  2391.0  3032.0     0     0
# 3        MD   44.0   42.0   40.0   38.0  ...  4375.0  6834.0  9348.0     0     0
# 4        MI  229.0  219.0  210.0  199.0  ...   852.0  1087.0  1692.0     0     0
#
# [5 rows x 21 columns]

# %%
import numpy as np

# %%
weights=fw.values

# %%
print(weights)
# Out:
# [['DE' 20.0 17.0 16.0 13.0 12.0 11.0 22.0 44.0 50.0 85.0 125.0 383.0
#   607.0 1001.0 1189.0 1230.0 1133.0 1354.0 0 0]
#  ['IL' 208.0 248.0 326.0 393.0 520.0 670.0 826.0 956.0 1054.0 1105.0
#   1286.0 1322.0 1565.0 1797.0 1892.0 1936.0 2029.0 2284.0 0 0]
#  ['IN' 33.0 35.0 38.0 37.0 63.0 78.0 91.0 100.0 102.0 128.0 134.0 168.0
#   185.0 488.0 1205.0 1713.0 2391.0 3032.0 0 0]
#  ['MD' 44.0 42.0 40.0 38.0 63.0 68.0 74.0 80.0 103.0 136.0 214.0 556.0
#   1432.0 2224.0 3449.0 4375.0 6834.0 9348.0 0 0]
#  ['MI' 229.0 219.0 210.0 199.0 224.0 274.0 335.0 405.0 408.0 432.0 466.0
#   568.0 752.0 765.0 816.0 852.0 1087.0 1692.0 0 0]
#  ['NC' 127.0 111.0 100.0 85.0 89.0 116.0 160.0 176.0 269.0 343.0 429.0
#   582.0 1974.0 4155.0 7898.0 13870.0 33396.0 49100.0 0 0]
#  ['NJ' 643.0 669.0 954.0 1205.0 1411.0 1629.0 1926.0 2241.0 2631.0 3350.0
#   4910.0 7854.0 14103.0 16749.0 19679.0 20963.0 22255.0 25629.0 0 0]
#  ['OH' 100.0 100.0 119.0 130.0 148.0 160.0 170.0 176.0 202.0 249.0 438.0
# ...

# %%
print(weights)
# Out:
# [['DE' 20.0 17.0 16.0 13.0 12.0 11.0 22.0 44.0 50.0 85.0 125.0 383.0
#   607.0 1001.0 1189.0 1230.0 1133.0 1354.0 0 0]
#  ['IL' 208.0 248.0 326.0 393.0 520.0 670.0 826.0 956.0 1054.0 1105.0
#   1286.0 1322.0 1565.0 1797.0 1892.0 1936.0 2029.0 2284.0 0 0]
#  ['IN' 33.0 35.0 38.0 37.0 63.0 78.0 91.0 100.0 102.0 128.0 134.0 168.0
#   185.0 488.0 1205.0 1713.0 2391.0 3032.0 0 0]
#  ['MD' 44.0 42.0 40.0 38.0 63.0 68.0 74.0 80.0 103.0 136.0 214.0 556.0
#   1432.0 2224.0 3449.0 4375.0 6834.0 9348.0 0 0]
#  ['MI' 229.0 219.0 210.0 199.0 224.0 274.0 335.0 405.0 408.0 432.0 466.0
#   568.0 752.0 765.0 816.0 852.0 1087.0 1692.0 0 0]
#  ['NC' 127.0 111.0 100.0 85.0 89.0 116.0 160.0 176.0 269.0 343.0 429.0
#   582.0 1974.0 4155.0 7898.0 13870.0 33396.0 49100.0 0 0]
#  ['NJ' 643.0 669.0 954.0 1205.0 1411.0 1629.0 1926.0 2241.0 2631.0 3350.0
#   4910.0 7854.0 14103.0 16749.0 19679.0 20963.0 22255.0 25629.0 0 0]
#  ['OH' 100.0 100.0 119.0 130.0 148.0 160.0 170.0 176.0 202.0 249.0 438.0
# ...

# %%
print(weights[11][18])
# Out:
# 126.0

# %%
sigma_W=fw.sum(axis=0)
print(sigma_W)
# Out:
# StateCode    DEILINMDMINCNJOHPATNVAWV
# 2000                             2066
# 2001                             2078
# 2002                             2452
# 2003                             2723
# 2004                             3214
# 2005                             3770
# 2006                             4500
# 2007                             5201
# 2008                             5961
# 2009                             7111
# 2010                            10040
# 2011                            15206
# 2012                            25792
# 2013                            33487
# 2014                            43070
# 2015                            52562
# 2016                            77818
# 2017                           105396
# 2018                                0
# 2018                                0
# dtype: object

# %%
sigma_W['2018']
# Out:
# 0

# %%
p=Path("/content/drive/My Drive/DatasetStates")
random.seed(0)
dirs=p.glob("*")

# %%
state_to_weight={"Illinois":"IL","Indiana":"IN","Michigan":"MI","New Jersey":"NJ","North Carolina":"NC","Pennysylvania":"PA","Tennessee":"TN","Virginia":"VA","West Virginia":"WV","delaware":"DE","maryland":"MD","ohio":"OH"}

# %%
print(state_to_weight)
# Out:
# {'Illinois': 'IL', 'Indiana': 'IN', 'Michigan': 'MI', 'New Jersey': 'NJ', 'North Carolina': 'NC', 'Pennysylvania': 'PA', 'Tennessee': 'TN', 'Virginia': 'VA', 'West Virginia': 'WV', 'delaware': 'DE', 'maryland': 'MD', 'ohio': 'OH'}

# %%
data_frames={"2000":pd.DataFrame(),"2001":pd.DataFrame(),"2002":pd.DataFrame(),"2003":pd.DataFrame(),"2004":pd.DataFrame(),"2005":pd.DataFrame(),
             "2006":pd.DataFrame(),"2007":pd.DataFrame(),"2008":pd.DataFrame(),"2009":pd.DataFrame(),"2010":pd.DataFrame(),"2011":pd.DataFrame(),
             "2012":pd.DataFrame(),"2013":pd.DataFrame(),"2014":pd.DataFrame(),"2015":pd.DataFrame(),"2016":pd.DataFrame(),"2017":pd.DataFrame(),
             "2018":pd.DataFrame()}

# %%
flag=False
for states in dirs:
  q=Path(str(states))
  random.seed(0)
  dir_states=q.glob("*")
  for file_state in dir_states:
    df=pd.read_csv(str(file_state),skiprows=2)
    df['Year']=df['Year'].astype(str)
    df['Month']=df['Month'].astype(str)
    df['date']=df["Year"].astype(str)+'/'+df["Month"].astype(str)+'/'+df['Day'].astype(str)
    # df['date']=pd.to_datetime(df['date'])
    df['datetime']=df['date']+' '+df['Hour'].astype(str)+':'+df['Minute'].astype(str)
    df['datetime']=pd.to_datetime(df['datetime'], format='%Y/%m/%d %H:%M')
    # df['datetime']=df['date']+' '+df['Hour'].astype(str)+':'+df['Minute'].astype(str)
    # df['datetime']=pd.to_datetime(df['datetime'], format='%Y/%m/%d %H:%M')
    print('dad')
    print(df['datetime'])
    print('daad')
    state_name=str(states).split("/")[-1]
    print(state_name)
    state_code=state_to_weight[state_name]
    ans=data_frames[str(df['Year'][1])]
    for i in range(12):
      print(i)
      str_temp=weights[i][0]
      print(str_temp+" "+state_code)
      if str_temp==state_code:
        # print("Found")
        year=int(df['Year'][1])
        if year==2018:
          continue
        col=year-1999
        # print(str(col)+"x")
        w=weights[i][col]
        # print(str(w)+"w")
        sigma=sigma_W[str(year)]
        # print(str(sigma)+"s")
        mul=w/sigma
        # print(mul+"x")
        print(type(mul))
        if ans.shape[0]==0:
          # print("Fuck")
          ans['DNI']=mul*df['DNI']
          # print("Fuck")
          ans['Pressure']=mul*df['Pressure']
          ans['Relative Humidity']=mul*df['Relative Humidity']
          ans['Temperature']=mul*df['Temperature']
          ans['Wind Speed']=mul*df['Wind Speed']
          ans['DHI']=mul*df['DHI']
          if(state_name=='New Jersey'):
            ans['datetime']=df['datetime']
          # print(df['datetime'])
        else:
          print("Fuck2")
          ans['DNI']=ans['DNI']+mul*df['DNI']
          ans['Pressure']=ans['Pressure']+mul*df['Pressure']
          ans['Relative Humidity']=ans['Relative Humidity']+mul*df['Relative Humidity']
          ans['Temperature']=ans['Temperature']+mul*df['Temperature']
          ans['Wind Speed']=ans['Wind Speed']+mul*df['Wind Speed']
          ans['DHI']=ans['DHI']+mul*df['DHI']
          # ans['datetime']=df['datetime']
          if(state_name=='New Jersey'):
            ans['datetime']=df['datetime']
          # if flag==False:
          #   ans['Day']=ans['Day']+df['Day']
          #   ans['Hour']=ans['Hour']+df['Hour']
          #   ans['Month']=ans['Month']+df['Month']
          #   ans['Minute']=ans['Minute']+df['Minute']
          #   ans['datetime']=ans['datetime']+df['datetime']
      
    data_frames[str(df['Year'][1])]=ans
    flag=True          
ans.head()
# Out:
# dad
# 0       2014-01-01 00:00:00
# 1       2014-01-01 00:30:00
# 2       2014-01-01 01:00:00
# 3       2014-01-01 01:30:00
# 4       2014-01-01 02:00:00
#                 ...
# 17515   2014-12-31 21:30:00
# 17516   2014-12-31 22:00:00
# 17517   2014-12-31 22:30:00
# 17518   2014-12-31 23:00:00
# 17519   2014-12-31 23:30:00
# Name: datetime, Length: 17520, dtype: datetime64[ns]
# daad
# North Carolina
# 0
# DE NC
# 1
# IL NC
# 2
# IN NC
# 3
# MD NC
# 4
# MI NC
# 5
# NC NC
# <class 'float'>
# Fuck2
# 6
# NJ NC
# 7
# OH NC
# 8
# PA NC
# 9
# TN NC
# 10
# VA NC
# 11
# WV NC
# dad
# 0       2012-01-01 00:00:00
# 1       2012-01-01 00:30:00
# 2       2012-01-01 01:00:00
# 3       2012-01-01 01:30:00
# 4       2012-01-01 02:00:00
#                 ...
# 17515   2012-12-31 21:30:00
# 17516   2012-12-31 22:00:00
# 17517   2012-12-31 22:30:00
# 17518   2012-12-31 23:00:00
# 17519   2012-12-31 23:30:00
# Name: datetime, Length: 17520, dtype: datetime64[ns]
# daad
# North Carolina
# 0
# DE NC
# ...

# %%
data_frames['2000'].head()
# Out:
#    DNI     Pressure  Relative Humidity  ...  Wind Speed  DHI            datetime
# 0  0.0  6896.819942         666.891026  ...   12.146370  0.0 2000-01-01 00:00:00
# 1  0.0  6896.819942         666.867343  ...   12.356438  0.0 2000-01-01 00:30:00
# 2  0.0  6896.819942         667.600987  ...   12.758616  0.0 2000-01-01 01:00:00
# 3  0.0  6893.668925         666.973156  ...   12.657018  0.0 2000-01-01 01:30:00
# 4  0.0  6893.668925         661.755624  ...   13.030058  0.0 2000-01-01 02:00:00
#
# [5 rows x 7 columns]

# %%
data_frames['2007'].shape
# Out:
# (17520, 7)

# %%
final=data_frames["2000"]
for i in data_frames:
  if(i!="2000"):
    final=pd.concat([final,data_frames[i]])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.

# %%
final.shape
# Out:
# (315360, 11)

# %%
final.dtypes
# Out:
# DHI                         float64
# DNI                         float64
# Day                         float64
# Hour                        float64
# Minute                      float64
# Month                        object
# Pressure                    float64
# Relative Humidity           float64
# Temperature                 float64
# Wind Speed                  float64
# datetime             datetime64[ns]
# dtype: object

# %%
final.head()
# Out:
#    DHI  DNI  Day  ...  Temperature  Wind Speed            datetime
# 0  0.0  0.0  NaN  ...    -1.135044   12.146370 2000-01-01 00:00:00
# 1  0.0  0.0  NaN  ...    -1.135044   12.356438 2000-01-01 00:30:00
# 2  0.0  0.0  NaN  ...    -1.717812   12.758616 2000-01-01 01:00:00
# 3  0.0  0.0  NaN  ...     0.538722   12.657018 2000-01-01 01:30:00
# 4  0.0  0.0  NaN  ...     0.999516   13.030058 2000-01-01 02:00:00
#
# [5 rows x 11 columns]

# %%
final.tail()
# Out:
#        DHI  DNI   Day  ...  Temperature  Wind Speed            datetime
# 17515  0.0  0.0  31.0  ...    22.177151   19.646490 2017-12-31 21:30:00
# 17516  0.0  0.0  31.0  ...    23.565581   19.521626 2017-12-31 22:00:00
# 17517  0.0  0.0  31.0  ...    19.987827   18.929519 2017-12-31 22:30:00
# 17518  0.0  0.0  31.0  ...    20.189267   18.518782 2017-12-31 23:00:00
# 17519  0.0  0.0  31.0  ...    19.868211   18.197540 2017-12-31 23:30:00
#
# [5 rows x 11 columns]

# %%
final.to_csv("/content/drive/My Drive/HUB/final.csv")

# %%
df=pd.read_csv("/content/drive/My Drive/HUB/final.csv")
df.tail()
# Out:
#         Unnamed: 0  DHI  DNI  ...  Temperature  Wind Speed             datetime
# 315355       17515  0.0  0.0  ...    22.177151   19.646490  2017-12-31 21:30:00
# 315356       17516  0.0  0.0  ...    23.565581   19.521626  2017-12-31 22:00:00
# 315357       17517  0.0  0.0  ...    19.987827   18.929519  2017-12-31 22:30:00
# 315358       17518  0.0  0.0  ...    20.189267   18.518782  2017-12-31 23:00:00
# 315359       17519  0.0  0.0  ...    19.868211   18.197540  2017-12-31 23:30:00
#
# [5 rows x 12 columns]

# %%
import pandas as pd
data=pd.read_csv("/content/final.csv")
data.head()
# Out:
#    Unnamed: 0  DHI  DNI  ...  Temperature  Wind Speed             datetime
# 0           0  0.0  0.0  ...    -1.135044   12.146370  2000-01-01 00:00:00
# 1           1  0.0  0.0  ...    -1.135044   12.356438  2000-01-01 00:30:00
# 2           2  0.0  0.0  ...    -1.717812   12.758616  2000-01-01 01:00:00
# 3           3  0.0  0.0  ...     0.538722   12.657018  2000-01-01 01:30:00
# 4           4  0.0  0.0  ...     0.999516   13.030058  2000-01-01 02:00:00
#
# [5 rows x 12 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# DHI                  float64
# DNI                  float64
# Day                  float64
# Hour                 float64
# Minute               float64
# Month                float64
# Pressure             float64
# Relative Humidity    float64
# Temperature          float64
# Wind Speed           float64
# datetime              object
# dtype: object

# %%
import datetime
data['date']=pd.to_datetime(data['datetime'], format="%Y-%m-%d %H:%M")
data['date']=data['date'].apply(lambda datetime:datetime.date())

# %%
final_data['DNI']=data.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-3eab5164aa2e> in <module>()
# ----> 1 final_data['DNI']=data.groupby()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7880
#    7881         if level is None and by is None:
# -> 7882             raise TypeError("You have to supply one of 'by' and 'level'")
#    7883         axis = self._get_axis_number(axis)
#    7884         return groupby(
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
data['date']=data['datetime'].strftime("%b %d %Y")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-d1d1af11ad84> in <module>()
# ----> 1 data['date']=data['datetime'].dt.strftime("%b %d %Y")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
# ...

# %%
final_data=pd.DataFrame()
# date['date']=data.datetime.apply(lambda datetime:datetime.date)
final_data['DNI']=data.groupby(data['date'])['DNI'].sum()

# %%
data.head()
# Out:
#    Unnamed: 0  DHI  DNI  ...  Wind Speed             datetime        date
# 0           0  0.0  0.0  ...   12.146370  2000-01-01 00:00:00  2000-01-01
# 1           1  0.0  0.0  ...   12.356438  2000-01-01 00:30:00  2000-01-01
# 2           2  0.0  0.0  ...   12.758616  2000-01-01 01:00:00  2000-01-01
# 3           3  0.0  0.0  ...   12.657018  2000-01-01 01:30:00  2000-01-01
# 4           4  0.0  0.0  ...   13.030058  2000-01-01 02:00:00  2000-01-01
#
# [5 rows x 13 columns]

# %%
final_data['Temperature']=data.groupby(data['date'])['Temperature'].sum()

# %%
final_data['DHI']=data.groupby(data['date'])['DHI'].sum()

# %%
final_data['Pressure']=data.groupby(data['date'])['Pressure'].sum()

# %%
final_data['Relative Humidity']=data.groupby(data['date'])['Relative Humidity'].sum()

# %%
final_data['Wind Speed']=data.groupby(data['date'])['Wind Speed'].sum()

# %%
final_data['Date']=data['date'].unique()

# %%
final_data.drop(['date'],axis=1)
# Out:
#                      DNI  Temperature  ...   Wind Speed        Date
# date                                   ...
# 2000-01-01  54381.133591  1037.862052  ...   598.086980  2000-01-01
# 2000-01-02  45372.732817  2351.387222  ...   994.235915  2000-01-02
# 2000-01-03  18265.523717  2618.137464  ...   980.512294  2000-01-03
# 2000-01-04   8845.210068  2477.440949  ...  1413.875218  2000-01-04
# 2000-01-05  61037.142304   -41.506776  ...  1064.319990  2000-01-05
# ...                  ...          ...  ...          ...         ...
# 2017-12-27  39219.025418  -849.206232  ...   664.777941  2017-12-27
# 2017-12-28  85404.015076 -1837.587698  ...   686.686792  2017-12-28
# 2017-12-29  69010.503719 -1232.687986  ...   550.056319  2017-12-29
# 2017-12-30  33516.047687  -760.913782  ...   590.597800  2017-12-30
# 2017-12-31  27181.258966 -1111.199173  ...   886.525815  2017-12-31
#
# [6570 rows x 7 columns]

# %%
final_data.tail()
# Out:
#                      DNI  Temperature  ...  Wind Speed        date
# date                                   ...
# 2017-12-27  39219.025418  -849.206232  ...  664.777941  2017-12-27
# 2017-12-28  85404.015076 -1837.587698  ...  686.686792  2017-12-28
# 2017-12-29  69010.503719 -1232.687986  ...  550.056319  2017-12-29
# 2017-12-30  33516.047687  -760.913782  ...  590.597800  2017-12-30
# 2017-12-31  27181.258966 -1111.199173  ...  886.525815  2017-12-31
#
# [5 rows x 7 columns]

# %%
final_data.dtypes
# Out:
# DNI                  float64
# Temperature          float64
# DHI                  float64
# Pressure             float64
# Relative Humidity    float64
# Wind Speed           float64
# dtype: object

# %%
data.head(n=24)
# Out:
#     Unnamed: 0         DHI  ...             datetime        date
# 0            0    0.000000  ...  2000-01-01 00:00:00  2000-01-01
# 1            1    0.000000  ...  2000-01-01 00:30:00  2000-01-01
# 2            2    0.000000  ...  2000-01-01 01:00:00  2000-01-01
# 3            3    0.000000  ...  2000-01-01 01:30:00  2000-01-01
# 4            4    0.000000  ...  2000-01-01 02:00:00  2000-01-01
# 5            5    0.000000  ...  2000-01-01 02:30:00  2000-01-01
# 6            6    0.000000  ...  2000-01-01 03:00:00  2000-01-01
# 7            7    0.000000  ...  2000-01-01 03:30:00  2000-01-01
# 8            8    0.000000  ...  2000-01-01 04:00:00  2000-01-01
# 9            9    0.000000  ...  2000-01-01 04:30:00  2000-01-01
# 10          10    0.000000  ...  2000-01-01 05:00:00  2000-01-01
# 11          11    0.000000  ...  2000-01-01 05:30:00  2000-01-01
# 12          12    0.000000  ...  2000-01-01 06:00:00  2000-01-01
# ...

# %%
df=pd.read_csv("/content/final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  DHI  DNI  ...  Temperature  Wind Speed             datetime
# 0           0  0.0  0.0  ...    -1.135044   12.146370  2000-01-01 00:00:00
# 1           1  0.0  0.0  ...    -1.135044   12.356438  2000-01-01 00:30:00
# 2           2  0.0  0.0  ...    -1.717812   12.758616  2000-01-01 01:00:00
# 3           3  0.0  0.0  ...     0.538722   12.657018  2000-01-01 01:30:00
# 4           4  0.0  0.0  ...     0.999516   13.030058  2000-01-01 02:00:00
#
# [5 rows x 12 columns]

# %%
ans=pd.DataFrame()

# %%
for tuple in df.itertuples():
  ans=ans.append(tuple+tuple[12].split(" ")[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-74e4f3fa00be> in <module>()
#       1 for tuple in df.itertuples():
# ----> 2   ans=ans.append(tuple+tuple[12].split(" ")[0])
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# DHI                  float64
# DNI                  float64
# Day                  float64
# Hour                 float64
# Minute               float64
# Month                float64
# Pressure             float64
# Relative Humidity    float64
# Temperature          float64
# Wind Speed           float64
# datetime              object
# date                  object
# dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0  ...                                               date
# 0           0  ...  <built-in method date of Timestamp object at 0...
# 1           1  ...  <built-in method date of Timestamp object at 0...
# 2           2  ...  <built-in method date of Timestamp object at 0...
# 3           3  ...  <built-in method date of Timestamp object at 0...
# 4           4  ...  <built-in method date of Timestamp object at 0...
#
# [5 rows x 13 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# DHI                  float64
# DNI                  float64
# Day                  float64
# Hour                 float64
# Minute               float64
# Month                float64
# Pressure             float64
# Relative Humidity    float64
# Temperature          float64
# Wind Speed           float64
# datetime              object
# date                  object
# dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0  DHI  DNI  ...  Wind Speed             datetime        date
# 0           0  0.0  0.0  ...   12.146370  2000-01-01 00:00:00  2000-01-01
# 1           1  0.0  0.0  ...   12.356438  2000-01-01 00:30:00  2000-01-01
# 2           2  0.0  0.0  ...   12.758616  2000-01-01 01:00:00  2000-01-01
# 3           3  0.0  0.0  ...   12.657018  2000-01-01 01:30:00  2000-01-01
# 4           4  0.0  0.0  ...   13.030058  2000-01-01 02:00:00  2000-01-01
#
# [5 rows x 13 columns]

# %%
gspc_df=pd.read_csv("/content/^GSPC (2).csv")

# %%
gspc_df.head()
# Out:
#          Date         Open         High  ...        Close    Adj Close      Volume
# 0  1999-12-31  1464.469971  1472.420044  ...  1469.250000  1469.250000   374050000
# 1  2000-01-03  1469.250000  1478.000000  ...  1455.219971  1455.219971   931800000
# 2  2000-01-04  1455.219971  1455.219971  ...  1399.420044  1399.420044  1009000000
# 3  2000-01-05  1399.420044  1413.270020  ...  1402.109985  1402.109985  1085500000
# 4  2000-01-06  1402.109985  1411.900024  ...  1403.449951  1403.449951  1092300000
#
# [5 rows x 7 columns]

# %%
gspc_df['Date']=pd.to_datetime(gspc_df['Date'],format='%Y-%m-%d')

# %%
pjm_df=pd.read_excel("/content/PJM West Hub.xls")

# %%
pjm_df.head(n=30)
# Out:
#    Price Hub Trade Date  ... Number of Companies       date
# 0   PJM West 2001-01-02  ...                   2 2001-01-02
# 1   PJM West 2001-01-03  ...                   2 2001-01-03
# 2   PJM West 2001-01-04  ...                   4 2001-01-04
# 3   PJM West 2001-01-08  ...                   2 2001-01-08
# 4   PJM West 2001-01-09  ...                   6 2001-01-09
# 5   PJM West 2001-01-10  ...                   4 2001-01-10
# 6   PJM West 2001-01-11  ...                   3 2001-01-11
# 7   PJM West 2001-01-12  ...                   6 2001-01-12
# 8   PJM West 2001-01-15  ...                   6 2001-01-15
# 9   PJM West 2001-01-16  ...                   7 2001-01-16
# 10  PJM West 2001-01-17  ...                   6 2001-01-17
# 11  PJM West 2001-01-18  ...                   5 2001-01-18
# 12  PJM West 2001-01-19  ...                   6 2001-01-19
# 13  PJM West 2001-01-22  ...                   4 2001-01-22
# 14  PJM West 2001-01-23  ...                   5 2001-01-23
# ...

# %%
final_data['Date']=pd.to_datetime(final_data['Date'])

# %%
pjm_df.columns
# Out:
# Index(['Price Hub', 'Trade Date', 'Delivery Start Date', 'Delivery End Date',
#        'High Price $/MWh', 'Low Price $/MWh', 'Wtd Avg Price $/MWh', 'Change',
#        'Daily Volume MWh', 'Number of Trades', 'Number of Companies'],
#       dtype='object')

# %%
final_data.head()
# Out:
#                      DNI  Temperature  ...   Wind Speed        date
# date                                   ...
# 2000-01-01  54381.133591  1037.862052  ...   598.086980  2000-01-01
# 2000-01-02  45372.732817  2351.387222  ...   994.235915  2000-01-02
# 2000-01-03  18265.523717  2618.137464  ...   980.512294  2000-01-03
# 2000-01-04   8845.210068  2477.440949  ...  1413.875218  2000-01-04
# 2000-01-05  61037.142304   -41.506776  ...  1064.319990  2000-01-05
#
# [5 rows x 7 columns]

# %%
final_data.to_csv("/content/sample_data/final_data.csv")

# %%
final_pjm_hub=pd.merge(pjm_df,final_data,how='left', left_on=['date'], right_on = ['Date'])

# %%
final_pjm_hub.head(30)
# Out:
#    Price Hub Trade Date Delivery Start Date  ...   Wind Speed      date_y       Date
# 0   PJM West 2001-01-02          2001-01-03  ...   908.896006  2001-01-02 2001-01-02
# 1   PJM West 2001-01-03          2001-01-04  ...   911.679211  2001-01-03 2001-01-03
# 2   PJM West 2001-01-04          2001-01-05  ...   839.573580  2001-01-04 2001-01-04
# 3   PJM West 2001-01-08          2001-01-09  ...   537.587199  2001-01-08 2001-01-08
# 4   PJM West 2001-01-09          2001-01-10  ...  1128.615640  2001-01-09 2001-01-09
# 5   PJM West 2001-01-10          2001-01-11  ...  1122.048893  2001-01-10 2001-01-10
# 6   PJM West 2001-01-11          2001-01-12  ...   805.587392  2001-01-11 2001-01-11
# 7   PJM West 2001-01-12          2001-01-15  ...   509.993840  2001-01-12 2001-01-12
# 8   PJM West 2001-01-15          2001-01-16  ...   680.033782  2001-01-15 2001-01-15
# 9   PJM West 2001-01-16          2001-01-17  ...   847.356497  2001-01-16 2001-01-16
# ...

# %%
final_pjm_hub.tail()
# Out:
#                   Price Hub Trade Date  ...      date_y       Date
# 3309  PJM-Wh Real Time Peak 2013-12-23  ...  2013-12-23 2013-12-23
# 3310  PJM-Wh Real Time Peak 2013-12-26  ...  2013-12-26 2013-12-26
# 3311  PJM-Wh Real Time Peak 2013-12-27  ...  2013-12-27 2013-12-27
# 3312  PJM-Wh Real Time Peak 2013-12-30  ...  2013-12-30 2013-12-30
# 3313  PJM-Wh Real Time Peak 2013-12-31  ...  2013-12-31 2013-12-31
#
# [5 rows x 20 columns]

# %%
final_snp=pd.merge(final_pjm_hub,gspc_df,how='left',left_on=['Trade Date'],right_on=['Date'])

# %%
final_snp.head(n=30)
# Out:
#    Price Hub Trade Date  ...    Adj Close        Volume
# 0   PJM West 2001-01-02  ...  1283.270020  1.129400e+09
# 1   PJM West 2001-01-03  ...  1347.560059  1.880700e+09
# 2   PJM West 2001-01-04  ...  1333.339966  2.131000e+09
# 3   PJM West 2001-01-08  ...  1295.859985  1.115500e+09
# 4   PJM West 2001-01-09  ...  1300.800049  1.191300e+09
# 5   PJM West 2001-01-10  ...  1313.270020  1.296500e+09
# 6   PJM West 2001-01-11  ...  1326.819946  1.411200e+09
# 7   PJM West 2001-01-12  ...  1318.550049  1.276000e+09
# 8   PJM West 2001-01-15  ...          NaN           NaN
# 9   PJM West 2001-01-16  ...  1326.650024  1.205700e+09
# 10  PJM West 2001-01-17  ...  1329.469971  1.349100e+09
# 11  PJM West 2001-01-18  ...  1347.969971  1.445000e+09
# 12  PJM West 2001-01-19  ...  1342.540039  1.407800e+09
# 13  PJM West 2001-01-22  ...  1342.900024  1.164000e+09
# 14  PJM West 2001-01-23  ...  1360.400024  1.232600e+09
# 15  PJM West 2001-01-24  ...  1364.300049  1.309000e+09
# ...

# %%
final_snp.to_csv('/content/dataset_merged.csv')

# %%
ff=pd.read_csv('/content/dataset_merged.csv')

# %%
ff.dtypes
# Out:
# Unnamed: 0               int64
# Price Hub               object
# Trade Date              object
# Delivery Start Date     object
# Delivery End Date       object
# High Price $/MWh       float64
# Low Price $/MWh        float64
# Wtd Avg Price $/MWh    float64
# Change                 float64
# Daily Volume MWh         int64
# Number of Trades         int64
# Number of Companies      int64
# date_x                  object
# DNI                    float64
# Temperature            float64
# DHI                    float64
# Pressure               float64
# Relative Humidity      float64
# Wind Speed             float64
# date_y                  object
# Date_x                  object
# Date_y                  object
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Adj Close              float64
# Volume                 float64
# dtype: object

# %%
ff.head()
# Out:
#    Unnamed: 0 Price Hub  Trade Date  ...        Close    Adj Close        Volume
# 0           0  PJM West  2001-01-02  ...  1283.270020  1283.270020  1.129400e+09
# 1           1  PJM West  2001-01-03  ...  1347.560059  1347.560059  1.880700e+09
# 2           2  PJM West  2001-01-04  ...  1333.339966  1333.339966  2.131000e+09
# 3           3  PJM West  2001-01-08  ...  1295.859985  1295.859985  1.115500e+09
# 4           4  PJM West  2001-01-09  ...  1300.800049  1300.800049  1.191300e+09
#
# [5 rows x 28 columns]
